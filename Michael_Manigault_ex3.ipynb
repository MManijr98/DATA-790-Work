# %%
import seaborn as sns  
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df_finalproject = pd.read_excel('MLB Diversity V2.xlsx', sheet_name=2)

# %%
df_finalproject
# Out:
#      year        ethnicity  of_players
# 0    1903           Latino    0.000000
# 1    1903            White    0.995000
# 2    1903  Native American    0.005000
# 3    1904           Latino    0.000000
# 4    1904            White    0.995037
# ..    ...              ...         ...
# 127  1945            White    0.962069
# 128  1945  Native American    0.008621
# 129  1946           Latino    0.014663
# 130  1946            White    0.976540
# 131  1946  Native American    0.008798
#
# [132 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.kdeplot(df_finalproject.of_players, ax=ax,                 
                     bw=0,               
                     shade=True,          
                     alpha=0.6
           )

ax.set_xlabel('players')
ax.set_ylabel('density')
ax.set_title('Amount of players in the MLB from 1902 to 1947')

ax.grid(axis='y')
ax.set_axisbelow(True)
plt.box(False)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.kdeplot(df_finalproject.of_players, ax=ax,                 
                     bw=1,               
                     shade=True,          
                     alpha=0.6
           )

ax.set_xlabel('players')
ax.set_ylabel('density')
ax.set_title('Amount of players in the MLB from 1902 to 1947')

ax.grid(axis='y')
ax.set_axisbelow(True)
plt.box(False)

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.kdeplot(df_finalproject.of_players, ax=ax,                 
                     bw=2,               
                     shade=True,          
                     alpha=0.6
           )

ax.set_xlabel('players')
ax.set_ylabel('density')
ax.set_title('Amount of players in the MLB from 1902 to 1947')

ax.grid(axis='y')
ax.set_axisbelow(True)
plt.box(False)

# %% [markdown]
# Out of all of the bandwidths used (0, 1 and 2), the bandwidth of 0 provides a more detailed graph depicting the amount of players in the MLB from 1902 to 1947. The amount of players in the dataset is measured in percentages in decimal form. As a result, the bandwidth should be zero due to it being greater than -1 and less than 1.
